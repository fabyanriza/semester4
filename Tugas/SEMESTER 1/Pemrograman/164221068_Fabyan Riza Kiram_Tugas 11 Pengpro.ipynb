# %%
for angka in range(101):
    if angka % 14 == 0:
        print('GENAP DAN SEVEN UP!')
    elif angka % 2 == 0:
        print('GENAP!')
    elif angka % 7 == 0:
        print('SEVEN UP!')
    else:
        print(angka)
# Out:
# GENAP DAN SEVEN UP!
# 1
# GENAP!
# 3
# GENAP!
# 5
# GENAP!
# SEVEN UP
# GENAP!
# 9
# GENAP!
# 11
# GENAP!
# 13
# GENAP DAN SEVEN UP!
# 15
# GENAP!
# 17
# GENAP!
# 19
# GENAP!
# SEVEN UP
# GENAP!
# 23
# GENAP!
# 25
# GENAP!
# 27
# GENAP DAN SEVEN UP!
# 29
# GENAP!
# 31
# GENAP!
# 33
# GENAP!
# SEVEN UP
# GENAP!
# 37
# GENAP!
# 39
# GENAP!
# 41
# GENAP DAN SEVEN UP!
# 43
# GENAP!
# 45
# GENAP!
# 47
# GENAP!
# SEVEN UP
# GENAP!
# 51
# GENAP!
# 53
# GENAP!
# 55
# GENAP DAN SEVEN UP!
# 57
# GENAP!
# 59
# GENAP!
# 61
# GENAP!
# SEVEN UP
# GENAP!
# 65
# GENAP!
# 67
# GENAP!
# 69
# GENAP DAN SEVEN UP!
# 71
# GENAP!
# 73
# GENAP!
# 75
# GENAP!
# SEVEN UP
# GENAP!
# 79
# GENAP!
# 81
# GENAP!
# 83
# GENAP DAN SEVEN UP!
# 85
# GENAP!
# 87
# GENAP!
# 89
# GENAP!
# SEVEN UP
# GENAP!
# 93
# GENAP!
# 95
# GENAP!
# 97
# GENAP DAN SEVEN UP!
# 99
# GENAP!

# %%
#Soal No.2

while True:
    try:
        tinggi = float(input('Masukkan tinggi badan anda (cm) :  '))
    except ValueError:
        print('Masukkan yang benar yaa:)')
        continue
    if tinggi <= 0:
        print('Sejak kapan tinggi badan negatif:D ')
    else:
        break

while True:
    try:
        berat = float(input('Masukkan berat badan anda(kg) : '))
    except ValueError:
        print('Pakai angka dong!')
        continue
    if berat <= 0:
        print('Berat badan kok negatif')
    else:
        break

tinggi_badan = tinggi / 100

BMI=b/(tinggi_badan)**2
akhir = round(BMI ,2)


if BMI < 18.50:
    print('BMI anda adalah',akhir ,'(kurang)')
elif 18.50 <= BMI < 25.00:
    print('BMI anda adalah',akhir ,'(normal)')
elif 25.00 <= BMI <30.00:
    print('BMI anda adalah',akhir ,'(berlebih)')
else:
    print('BMI anda adalah',akhir ,'(obesitas)')
# Out:
# Masukkan tinggi badan anda (cm) :  174
# Masukkan berat badan anda(kg) : 83
# BMI anda adalah 27.41 (berlebih)
